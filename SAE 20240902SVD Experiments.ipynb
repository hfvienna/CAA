# %%
"""
1. Should the code not run, try upgrading transformers in your env:
pip install --upgrade transformers

2. The next cell is a system path fix. It may or may not be necessary to run in your environment.
"""
# Out:
# '\n1. Should the code not run, try upgrading transformers in your env:\npip install --upgrade transformers\n\n2. The next cell is a system path fix. It may or may not be necessary to run in your environment.\n'

# %%
# TRANSFORMER / ENVIRONMENT FIX
import sys
sys.path.append('/root/CAA/venv/lib/python3.10/site-packages')
print(sys.path)
# Out:
# ['/opt/conda/lib/python310.zip', '/opt/conda/lib/python3.10', '/opt/conda/lib/python3.10/lib-dynload', '', '/opt/conda/lib/python3.10/site-packages', '/root/CAA/venv/lib/python3.10/site-packages']

# %%
import json
import os
import random
import time

import matplotlib.pyplot as plt
import numpy as np
import requests
import torch
import torch.nn as nn
import torch.nn.functional as F
from dotenv import load_dotenv
from huggingface_hub import hf_hub_download

from behaviors import ALL_BEHAVIORS, BASE_DIR, COORDINATE, get_vector_path
from gemma_2_wrapper import Gemma2Wrapper
from generate_vectors import generate_save_vectors_for_behavior
import gemma_vector_analysis

# %%
load_dotenv()
HUGGINGFACE_TOKEN = os.getenv("HF_TOKEN")
NEURONPEDIA_API_KEY = os.getenv("NEURONPEDIA_API_KEY")

# %%
# FINAL CODE I USE TO CONTINUE RESEARCH
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
layer = 14

sae_model_name = "google/gemma-scope-2b-pt-res" #Careful, on Neuronpedia this has to be referred to as gemma-2-2b
path_to_params = hf_hub_download(
    repo_id=sae_model_name,
    filename=f"layer_{layer}/width_16k/average_l0_84/params.npz", #This model (width and sparsity is used on Neuronpedia)
    force_download=False,
)

params = np.load(path_to_params)
pt_params = {k: torch.from_numpy(v).to(device) for k, v in params.items()}

class JumpReLUSAE(nn.Module):
    def __init__(self, d_model, d_sae):
        super().__init__()
        self.W_enc = nn.Parameter(torch.zeros(d_model, d_sae))
        self.W_dec = nn.Parameter(torch.zeros(d_sae, d_model))
        self.threshold = nn.Parameter(torch.zeros(d_sae))
        self.b_enc = nn.Parameter(torch.zeros(d_sae))
        self.b_dec = nn.Parameter(torch.zeros(d_model))

    def encode(self, input_acts):
        pre_acts = input_acts @ self.W_enc + self.b_enc
        mask = (pre_acts > self.threshold)
        acts = mask * torch.nn.functional.relu(pre_acts)
        return acts

    def decode(self, acts):
        return acts @ self.W_dec + self.b_dec

    def forward(self, acts):
        acts = self.encode(acts)
        recon = self.decode(acts)
        return recon
        
    def process_caa_vector(self, caa_vector, scale_factor=4.2813): #This works empirically to return a high cosine similary; not based on theory
        caa_vector = caa_vector.to(self.W_enc.device)
        decoder_bias = self.b_dec

        # Apply scaling to the CAA vector
        caa_vector = caa_vector * scale_factor

        # Compute SAE(caa_vector + decoder_bias) and SAE(-caa_vector + decoder_bias)
        positive_encoded = self.encode(caa_vector + decoder_bias)
        negative_encoded = self.encode(-caa_vector + decoder_bias)
        
        positive_decoded = self.decode(positive_encoded)
        negative_decoded = self.decode(negative_encoded)
        
        # Calculate (positive - negative) / 2
        result_vector = (positive_decoded - negative_decoded) / 2
        
        # Calculate cosine similarity between result_vector and caa_vector
        cosine_sim = F.cosine_similarity(result_vector.view(1, -1), caa_vector.view(1, -1), dim=1).item()
        
        return result_vector, cosine_sim

#CAA vectors into SAE basis

def process_caa_vectors(sae, caa_vectors, scale_factor=4.2813):
    processed_vectors = {}
    similarities = []
    
    for behavior, caa_vector in caa_vectors.items():
        caa_vector = caa_vector.to(device)
        
        # Process the CAA vector with scaling
        processed_vector, cosine_sim = sae.process_caa_vector(caa_vector, scale_factor=scale_factor)
        
        similarities.append(cosine_sim)
        
        processed_vectors[behavior] = processed_vector.cpu()
        
        print(f"Processed vector for behavior: {behavior}")
        print(f"Cosine similarity: {cosine_sim:.4f}")
        print(f"Original L2 norm: {torch.norm(caa_vector).item():.4f}")
        print(f"Processed L2 norm: {torch.norm(processed_vector).item():.4f}")
        print(f"Original mean: {torch.mean(caa_vector).item():.4f}")
        print(f"Processed mean: {torch.mean(processed_vector).item():.4f}")
        print(f"Original std dev: {torch.std(caa_vector).item():.4f}")
        print(f"Processed std dev: {torch.std(processed_vector).item():.4f}")
        print()
    
    avg_similarity = np.mean(similarities)
    print(f"Average cosine similarity: {avg_similarity:.4f}")
    
    return processed_vectors

# Load the SAE model
sae = JumpReLUSAE(params['W_enc'].shape[0], params['W_enc'].shape[1])
sae.load_state_dict(pt_params)
sae = sae.to(device)
print("SAE loaded successfully")

# Load CAA vectors
caa_vectors = {}
for behavior in ALL_BEHAVIORS:
    layer = 14
    model_name_path = 'gemma-2-2b'#See above, different naming required here
    vector_path = gemma_vector_analysis.fix_vector_path(get_vector_path(behavior, layer, model_name_path))
    normalized_dir = os.path.join(BASE_DIR, 'normalized_vectors', behavior)
    
    original_path = os.path.join(normalized_dir, f"vec_layer_{layer}_{model_name_path}.pt")
    original_path = gemma_vector_analysis.fix_vector_path(original_path)
    caa_vector = torch.load(original_path)
    caa_vectors[behavior] = caa_vector
    print(f"Loaded CAA vector for behavior: {behavior}")

# Process CAA vectors with scaling
processed_vectors = process_caa_vectors(sae, caa_vectors, scale_factor=4.2813)

# Save processed vectors
sae_vector_dir = '/root/CAA/sae_vector'
if not os.path.exists(sae_vector_dir):
    os.makedirs(sae_vector_dir)

for behavior, processed_vector in processed_vectors.items():
    save_path = os.path.join(sae_vector_dir, f"processed_{behavior}.pt")
    torch.save(processed_vector, save_path)
    print(f"Saved processed vector for behavior {behavior} at {save_path}")

print("CAA vector processing complete.")
# Out:
# SAE loaded successfully
# Loaded CAA vector for behavior: coordinate-other-ais
# Loaded CAA vector for behavior: corrigible-neutral-HHH
# Loaded CAA vector for behavior: hallucination
# Loaded CAA vector for behavior: myopic-reward
# Loaded CAA vector for behavior: survival-instinct
# Loaded CAA vector for behavior: sycophancy
# Loaded CAA vector for behavior: refusal
# Processed vector for behavior: coordinate-other-ais
# Cosine similarity: 0.8658
# Original L2 norm: 44.3626
# Processed L2 norm: 255.2028
# Original mean: 0.0521
# Processed mean: 0.1877
# Original std dev: 0.9230
# Processed std dev: 5.3146
#
# Processed vector for behavior: corrigible-neutral-HHH
# Cosine similarity: 0.8685
# Original L2 norm: 44.3626
# Processed L2 norm: 268.3082
# Original mean: 0.0128
# Processed mean: 0.0354
# Original std dev: 0.9243
# Processed std dev: 5.5909
#
# Processed vector for behavior: hallucination
# Cosine similarity: 0.8456
# Original L2 norm: 44.3626
# Processed L2 norm: 241.0766
# Original mean: 0.0288
# Processed mean: 0.1753
# Original std dev: 0.9240
# Processed std dev: 5.0205
#
# Processed vector for behavior: myopic-reward
# Cosine similarity: 0.8897
# Original L2 norm: 44.3626
# Processed L2 norm: 193.2522
# Original mean: 0.0039
# Processed mean: -0.0211
# Original std dev: 0.9244
# Processed std dev: 4.0269
#
# Processed vector for behavior: survival-instinct
# Cosine similarity: 0.8538
# Original L2 norm: 44.3626
# Processed L2 norm: 212.8642
# Original mean: -0.0186
# Processed mean: -0.0488
# Original std dev: 0.9242
# Processed std dev: 4.4354
#
# Processed vector for behavior: sycophancy
# Cosine similarity: 0.8502
# Original L2 norm: 44.3626
# Processed L2 norm: 207.0221
# Original mean: 0.0089
# Processed mean: 0.0609
# Original std dev: 0.9244
# Processed std dev: 4.3135
#
# Processed vector for behavior: refusal
# Cosine similarity: 0.8543
# Original L2 norm: 44.3626
# Processed L2 norm: 232.5123
# Original mean: -0.0370
# Processed mean: -0.2305
# Original std dev: 0.9237
# Processed std dev: 4.8396
#
# Average cosine similarity: 0.8611
# Saved processed vector for behavior coordinate-other-ais at /root/CAA/sae_vector/processed_coordinate-other-ais.pt
# Saved processed vector for behavior corrigible-neutral-HHH at /root/CAA/sae_vector/processed_corrigible-neutral-HHH.pt
# Saved processed vector for behavior hallucination at /root/CAA/sae_vector/processed_hallucination.pt
# Saved processed vector for behavior myopic-reward at /root/CAA/sae_vector/processed_myopic-reward.pt
# Saved processed vector for behavior survival-instinct at /root/CAA/sae_vector/processed_survival-instinct.pt
# Saved processed vector for behavior sycophancy at /root/CAA/sae_vector/processed_sycophancy.pt
# Saved processed vector for behavior refusal at /root/CAA/sae_vector/processed_refusal.pt
# CAA vector processing complete.

# %%
# NORMALIZE all processed vectors to the norm of one of the original CAA vectors

# Get the norm of the first original CAA vector (they all have the same norm)
example_caa_vector = next(iter(caa_vectors.values()))
original_norm = torch.norm(example_caa_vector).item()
print(f"Original CAA vector norm: {original_norm:.4f}")

# Create a directory for the normalized vectors
normalized_vector_dir = '/root/CAA/sae_vector_normalized'
if not os.path.exists(normalized_vector_dir):
    os.makedirs(normalized_vector_dir)

# Normalize and save the processed vectors
for behavior, processed_vector in processed_vectors.items():
    # Compute the norm of the processed vector
    processed_norm = torch.norm(processed_vector).item()
    
    # Normalize the processed vector to the original norm
    normalized_vector = processed_vector * (original_norm / processed_norm)
    
    # Save the normalized vector
    save_path = os.path.join(normalized_vector_dir, f"normalized_{behavior}.pt")
    torch.save(normalized_vector, save_path)
    
    # Print norms
    print(f"Processed vector norm for behavior {behavior}: {processed_norm:.4f}")
    print(f"Normalized vector norm for behavior {behavior}: {torch.norm(normalized_vector).item():.4f}")

print("Normalization of processed vectors complete.")
# Out:
# Original CAA vector norm: 44.3626
# Processed vector norm for behavior coordinate-other-ais: 255.2028
# Normalized vector norm for behavior coordinate-other-ais: 44.3626
# Processed vector norm for behavior corrigible-neutral-HHH: 268.3082
# Normalized vector norm for behavior corrigible-neutral-HHH: 44.3626
# Processed vector norm for behavior hallucination: 241.0766
# Normalized vector norm for behavior hallucination: 44.3626
# Processed vector norm for behavior myopic-reward: 193.2522
# Normalized vector norm for behavior myopic-reward: 44.3626
# Processed vector norm for behavior survival-instinct: 212.8642
# Normalized vector norm for behavior survival-instinct: 44.3626
# Processed vector norm for behavior sycophancy: 207.0221
# Normalized vector norm for behavior sycophancy: 44.3626
# Processed vector norm for behavior refusal: 232.5123
# Normalized vector norm for behavior refusal: 44.3626
# Normalization of processed vectors complete.

# %%
# Assuming sae, caa_vectors, device, and sae_vector_dir are already defined

def analyze_behavior_vector(behavior, caa_vector):
    caa_vector = caa_vector.to(device)
    
    # Process the CAA vector through the encoder to get the encoded (SAE basis) vector
    encoded_vector = sae.encode(caa_vector * 4.2813 + sae.b_dec)
    
    # Calculate the squared values of the encoded vector
    squared_values = encoded_vector ** 2
    
    # Calculate the total sum of squared values
    total_squared_sum = torch.sum(squared_values).item()
    
    # Calculate the contribution of each feature
    feature_contributions = []
    for i, feature_value in enumerate(encoded_vector):
        feature_squared = feature_value.item() ** 2
        percentage = (feature_squared / total_squared_sum) * 100 if total_squared_sum != 0 else 0
        feature_contributions.append((i, feature_value.item(), percentage))
    
    # Sort features by their contribution (descending order)
    sorted_features = sorted(feature_contributions, key=lambda x: x[2], reverse=True)
    
    return sorted_features, torch.sqrt(torch.tensor(total_squared_sum)).item()

# Analyze each behavior
behavior_analyses = {}

for behavior, caa_vector in caa_vectors.items():
    sorted_features, total_norm = analyze_behavior_vector(behavior, caa_vector)
    behavior_analyses[behavior] = {
        "sorted_features": sorted_features,
        "total_norm": total_norm
    }

# Print results
for behavior, analysis in behavior_analyses.items():
    print(f"\nBehavior: {behavior}")
    print(f"Total norm: {analysis['total_norm']:.4f}")
    print("Top 10 contributing features:")
    for i, (feature_index, feature_value, percentage) in enumerate(analysis['sorted_features'][:10], 1):
        print(f"  {i}. Feature {feature_index}: {percentage:.2f}% (value: {feature_value:.4f})")
    
    # Count non-zero features
    non_zero_count = sum(1 for _, value, _ in analysis['sorted_features'] if abs(value) > 1e-6)
    print(f"Number of non-zero features: {non_zero_count}")

# Optionally, save the analysis results
save_path = os.path.join(sae_vector_dir, "behavior_feature_analysis.pt")
torch.save(behavior_analyses, save_path)
print(f"\nBehavior feature analysis saved to {save_path}")
# Out:
# Behavior: coordinate-other-ais
# Total norm: 159.8280
# Top 10 contributing features:
#   1. Feature 10414: 16.71% (value: 65.3287)
#   2. Feature 10781: 2.48% (value: 25.1675)
#   3. Feature 715: 2.40% (value: 24.7662)
#   4. Feature 11139: 2.17% (value: 23.5419)
#   5. Feature 2721: 2.03% (value: 22.7471)
#   6. Feature 11113: 1.50% (value: 19.5599)
#   7. Feature 4121: 1.30% (value: 18.2298)
#   8. Feature 11500: 1.28% (value: 18.1127)
#   9. Feature 294: 1.21% (value: 17.5502)
#   10. Feature 1830: 1.57% (value: 17.3827)
# Number of non-zero features: 343
#
# Behavior: refusal
# Total norm: 150.2682
# Top 10 contributing features:
#   1. Feature 15297: 3.58% (value: 28.4289)
#   2. Feature 1538: 3.55% (value: 28.3076)
#   3. Feature 13748: 3.14% (value: 26.6420)
#   4. Feature 1462: 3.07% (value: 26.3455)
#   5. Feature 6648: 3.01% (value: 26.0690)
#   6. Feature 9286: 1.96% (value: 21.0437)
#   7. Feature 14929: 1.55% (value: 18.7217)
#   8. Feature 1618: 1.55% (value: 18.7019)
#   9. Feature 9868: 1.48% (value: 18.2508)
#   10. Feature 12085: 1.36% (value: 17.5409)
# Number of non-zero features: 364
#
# Behavior feature analysis saved to /root/CAA/sae_vector/behavior_feature_analysis.pt

# %%
# Neuronpedia API Information
API_KEY = os.getenv("NEURONPEDIA_API_KEY")
API_URL = "https://www.neuronpedia.org/api/feature/{modelId}/{layer}/{index}"

def fetch_feature_explanation(model_id, layer, index, max_retries=3):
    if not API_KEY:
        return f"Feature {index}: No API key provided. Unable to fetch explanation."

    url = API_URL.format(modelId=model_id, layer=layer, index=index)
    headers = {
        "X-Api-Key": API_KEY
    }
    
    for attempt in range(max_retries):
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            data = response.json()
            
            explanations = data.get("explanations", [])
            if explanations:
                return explanations[0].get("description", "No description available")
            else:
                return "No explanation available from API"
        except requests.exceptions.RequestException as err:
            print(f"Error occurred (attempt {attempt + 1}/{max_retries}): {err}")
            if attempt < max_retries - 1:
                time.sleep(2)
    
    return f"Feature {index}: Failed to retrieve explanation after {max_retries} attempts"

# Process and sort features by impact for behavior
model_id = "gemma-2-2b"
layer_id = "14-gemmascope-res-16k"
behavior = "refusal"

# Assuming caa_vectors and sae are defined elsewhere in your code
caa_vector = caa_vectors[behavior].to(device)
encoded_vector = sae.encode(caa_vector * 4.2813 + sae.b_dec)

non_zero_indices_encoded = torch.nonzero(encoded_vector).squeeze()
non_zero_activations = encoded_vector[non_zero_indices_encoded]

impacts = []
component_vectors = {}
for i, index in enumerate(non_zero_indices_encoded):
    contribution_vector = sae.W_dec[index, :] * non_zero_activations[i]
    impact = torch.norm(contribution_vector).item()
    impacts.append((index.item(), impact))
    component_vectors[index.item()] = contribution_vector

impacts_sorted = sorted(impacts, key=lambda x: x[1], reverse=True)[:364]

# Calculate and print the norm of the original refusal vector
original_norm = torch.norm(caa_vector).item()
print(f"Norm of original refusal vector: {original_norm:.4f}")

# Fetch explanations for top k features
top_features_with_explanations = []
for index, impact in impacts_sorted:
    explanation = fetch_feature_explanation(model_id, layer_id, index)
    component_vector = component_vectors[index]
    component_norm = torch.norm(component_vector).item()
    top_features_with_explanations.append((index, impact, explanation, component_vector, component_norm))
    print(f"Feature {index}: {explanation}")
    print(f"Component vector norm: {component_norm:.4f}")

# Print the top features with explanations
print(f"Behavior: {behavior}")
print(f"Top features by impact (index, impact, explanation, component norm):")
for index, impact, explanation, component_vector, component_norm in top_features_with_explanations:
    print(f"Index: {index}, Impact: {impact:.4f}, Component Norm: {component_norm:.4f}")
    print(f"Explanation: {explanation}")
    print()

sae_vector_dir = f"sae_vector_features/{behavior}"
os.makedirs(sae_vector_dir, exist_ok=True)

for index, impact, explanation, component_vector, component_norm in top_features_with_explanations:
    feature_save_path = os.path.join(sae_vector_dir, f"feature_{index}_component_vector.pt")
    torch.save(component_vector, feature_save_path)
    print(f"Component vector for feature {index} saved to {feature_save_path}")
    print(f"Dimension of component vector for feature {index}: {component_vector.shape}")

save_path = os.path.join(sae_vector_dir, "top_364_features_explanations_refusal.pt")
torch.save(top_features_with_explanations, save_path)
print(f"Top k feature explanations and component vectors by impact saved to {save_path}")

# Save the top k features data and component vectors to files
sae_vector_dir = f"sae_vector_features/{behavior}"
os.makedirs(sae_vector_dir, exist_ok=True)

for index, impact, explanation, component_vector, component_norm in top_features_with_explanations:
    feature_save_path = os.path.join(sae_vector_dir, f"feature_{index}_component_vector.pt")
    torch.save(component_vector, feature_save_path)
    print(f"Component vector for feature {index} saved to {feature_save_path}")

save_path = os.path.join(sae_vector_dir, "top_364_features_explanations_refusal.pt")
torch.save(top_features_with_explanations, save_path)
print(f"Top k feature explanations and component vectors by impact saved to {save_path}")
# Out:
# Norm of original refusal vector: 44.3626
# Feature 15297: Feature 15297: No API key provided. Unable to fetch explanation.
# Component vector norm: 28.4289
# Feature 1538: Feature 1538: No API key provided. Unable to fetch explanation.
# Component vector norm: 28.3076
# Feature 13748: Feature 13748: No API key provided. Unable to fetch explanation.
# Component vector norm: 26.6420
# Feature 1462: Feature 1462: No API key provided. Unable to fetch explanation.
# Component vector norm: 26.3455
# Feature 6648: Feature 6648: No API key provided. Unable to fetch explanation.
# Component vector norm: 26.0690
# Feature 9286: Feature 9286: No API key provided. Unable to fetch explanation.
# Component vector norm: 21.0437
# Feature 14929: Feature 14929: No API key provided. Unable to fetch explanation.
# Component vector norm: 18.7217
# Feature 1618: Feature 1618: No API key provided. Unable to fetch explanation.
# Component vector norm: 18.7019
# Feature 9868: Feature 9868: No API key provided. Unable to fetch explanation.
# Component vector norm: 18.2508
# Feature 12085: Feature 12085: No API key provided. Unable to fetch explanation.
# Component vector norm: 17.5409
# Feature 3481: Feature 3481: No API key provided. Unable to fetch explanation.
# Component vector norm: 16.7142
# Feature 14659: Feature 14659: No API key provided. Unable to fetch explanation.
# Component vector norm: 16.2275
# Feature 3371: Feature 3371: No API key provided. Unable to fetch explanation.
# Component vector norm: 16.1159
# Feature 5098: Feature 5098: No API key provided. Unable to fetch explanation.
# Component vector norm: 15.7795
# Feature 14894: Feature 14894: No API key provided. Unable to fetch explanation.
# Component vector norm: 15.3791
# Feature 5880: Feature 5880: No API key provided. Unable to fetch explanation.
# Component vector norm: 15.0852
# Feature 5754: Feature 5754: No API key provided. Unable to fetch explanation.
# Component vector norm: 14.5094
# Feature 3504: Feature 3504: No API key provided. Unable to fetch explanation.
# Component vector norm: 14.4133
# Feature 10549: Feature 10549: No API key provided. Unable to fetch explanation.
# Component vector norm: 13.9211
# Feature 1689: Feature 1689: No API key provided. Unable to fetch explanation.
# Component vector norm: 13.5786
# Feature 15887: Feature 15887: No API key provided. Unable to fetch explanation.
# Component vector norm: 13.5775
# Feature 13149: Feature 13149: No API key provided. Unable to fetch explanation.
# Component vector norm: 13.5714
# Feature 14769: Feature 14769: No API key provided. Unable to fetch explanation.
# Component vector norm: 12
No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1931
# Feature 4367: Feature 4367: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1786
# Feature 5720: Feature 5720: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1709
# Feature 15431: Feature 15431: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1491
# Feature 1878: Feature 1878: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1477
# Feature 9651: Feature 9651: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1392
# Feature 3565: Feature 3565: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1237
# Feature 3913: Feature 3913: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1171
# Feature 6428: Feature 6428: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1115
# Feature 15890: Feature 15890: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.1032
# Feature 12362: Feature 12362: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0983
# Feature 3952: Feature 3952: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0966
# Feature 13880: Feature 13880: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0768
# Feature 1980: Feature 1980: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0767
# Feature 7507: Feature 7507: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0702
# Feature 13083: Feature 13083: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0511
# Feature 325: Feature 325: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0371
# Feature 7017: Feature 7017: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0262
# Feature 8559: Feature 8559: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0078
# Feature 10449: Feature 10449: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0065
# Feature 778: Feature 778: No API key provided. Unable to fetch explanation.
# Component vector norm: 4.0010
# Feature 10509: Feature 10509: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9815
# Feature 13241: Feature 13241: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9725
# Feature 14461: Feature 14461: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9690
# Feature 1110: Feature 1110: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9429
# Feature 3685: Feature 3685: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9399
# Feature 9247: Feature 9247: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9348
# Feature 6067: Feature 6067: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9307
# Feature 15109: Feature 15109: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9294
# Feature 8642: Feature 8642: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9244
# Feature 5903: Feature 5903: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9120
# Feature 5990: Feature 5990: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.9110
# Feature 16210: Feature 16210: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.8900
# Feature 9735: Feature 9735: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.8818
# Feature 14336: Feature 14336: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.8814
# Feature 12384: Feature 12384: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.8725
# Feature 933: Feature 933: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.8723
# Feature 3903: Feature 3903: No API key provided. Unable to fetch explanation.
# Component vector norm: 3.8658
# Behavior: refusal
# Top features by impact (index, impact, explanation, component norm):
# Index: 15297, Impact: 28.4289, Component Norm: 28.4289
# Explanation: Feature 15297: No API key provided. Unable to fetch explanation.
#
# Index: 1538, Impact: 28.3076, Component Norm: 28.3076
# Explanation: Feature 1538: No API key provided. Unable to fetch explanation.
#
# Index: 13748, Impact: 26.6420, Component Norm: 26.6420
# Explanation: Feature 13748: No API key provided. Unable to fetch explanation.
#
# Index: 1462, Impact: 26.3455, Component Norm: 26.3455
# Explanation: Feature 1462: No API key provided. Unable to fetch explanation.
#
# Index: 6648, Impact: 26.0690, Component Norm: 26.0690
# Explanation: Feature 6648: No API key provided. Unable to fetch explanation.
#
# Index: 9286, Impact: 21.0437, Component Norm: 21.0437
# Explanation: Feature 9286: No API key provided. Unable to fetch explanation.
#
# Index: 14929, Impact: 18.7217, Component Norm: 18.7217
# Explanation: Feature 14929: No API key provided. Unable to fetch explanation.
#
# Index: 1618, Impact: 18.7019, Component Norm: 18.7019
# Explanation: Feature 1618: No API key provided. Unable to fetch explanation.
#
# Index: 9868, Impact: 18.2508, Component Norm: 18.2508
# Explanation: Feature 9868: No API key provided. Unable to fetch explanation.
#
# Index: 12085, Impact: 17.5409, Component Norm: 17.5409
# Explanation: Feature 12085: No API key provided. Unable to fetch explanation.
#
# Index: 3481, Impact: 16.7142, Component Norm: 16.7142
# Explanation: Feature 3481: No API key provided. Unable to fetch explanation.
#
# Index: 14659, Impact: 16.2275, Component Norm: 16.2275
# Explanation: Feature 14659: No API key provided. Unable to fetch explanation.
#
# Index: 3371, Impact: 16.1159, Component Norm: 16.1159
# Explanation: Feature 3371: No API key provided. Unable to fetch explanation.
#
# Index: 5098, Impact: 15.7795, Component Norm: 15.7795
# Explanation: Feature 5098: No API key provided. Unable to fetch explanation.
#
# Index: 14894, Impact: 15.3791, Component Norm: 15.3791
# Explanation: Feature 14894: No API key provided. Unable to fetch explanation.
#
# Index: 5880, Impact: 15.0852, Component Norm: 15.0852
# Explanation: Feature 5880: No API key provided. Unable to fetch explanation.
#
# Index: 5754, Impact: 14.5094, Component Norm: 14.5094
# Explanation: Feature 5754: No API key provided. Unable to fetch explanation.
#
# Index: 3504, Impact: 14.4133, Component Norm: 14.4133
# Explanation: Feature 3504: No API key provided. Unable to fetch explanation.
#
# Index: 10549, Impact: 13.9211, Component Norm: 13.9211
# Explanation: Feature 10549: No API key provided. Unable to fetch explanation.
#
# Index: 1689, Impact: 13.5786, Component Norm: 13.5786
# Explanation: Feature 1689: No API key provided. Unable to fetch explanation.
#
# Index: 15887, Impact: 13.5775, Component Norm: 13.5775
# Explanation: Feature 15887: No API key provided. Unable to fetch explanation.
#
# Index: 13149, Impact: 13.5714, Component Norm: 13.5714
# Explanation: Feature 13149: No API key provided. Unable to fetch explanation.
#
# Index: 14769, Impact: 12.8865, Component Norm: 12.8865
# Explanation: Feature 14769: No API key provided. Unable to fetch explanation.
#
# Index: 3938, Impact: 12.6545, Component Norm: 12.6545
# Explanation: Feature 3938: No API key provided. Unable to fetch explanation.
#
# Index: 14419, Impact: 12.4123, Component Norm: 12.4123
# Explanation: Feature 14419: No API key provided. Unable to fetch explanation.
#
# Index: 6064, Impact: 12.3480, Component Norm: 12.3480
# Explanation: Feature 6064: No API key provided. Unable to fetch explanation.
#
# Index: 10423, Impact: 12.3279, Component Norm: 12.3279
# Explanation: Feature 10423: No API key provided. Unable to fetch explanation.
#
# Index: 10153, Impact: 12.1540, Component Norm: 12.1540
# Explanation: Feature 10153: No API key provided. Unable to fetch explanation.
#
# Index: 15056, Impact: 12.1206, Component Norm: 12.1206
# Explanation: Feature 15056: No API key provided. Unable to fetch explanation.
#
# Index: 15404, Impact: 12.0818, Component Norm: 12.0818
# Explanation: Feature 15404: No API key provided. Unable to fetch explanation.
#
# Index: 1028, Impact: 11.8620, Component Norm: 11.8620
# Explanation: Feature 1028: No API key provided. Unable to fetch explanation.
#
# Index: 15979, Impact: 11.6268, Component Norm: 11.6268
# Explanation: Feature 15979: No API key provided. Unable to fetch explanation.
#
# Index: 10430, Impact: 11.5845, Component Norm: 11.5845
# Explanation: Feature 10430: No API key provided. Unable to fetch explanation.
#
# Index: 648, Impact: 11.5539, Component Norm: 11.5539
# Explanation: Feature 648: No API key provided. Unable to fetch explanation.
#
# Index: 15881, Impact: 11.5245, Component Norm: 11.5245
# Explanation: Feature 15881: No API key provided. Unable to fetch explanation.
#
# Index: 11293, Impact: 11.4107, Component Norm: 11.4107
# Explanation: Feature 11293: No API key provided. Unable to fetch explanation.
#
# Index: 943, Impact: 11.3092, Component Norm: 11.3092
# Explanation: Feature 943: No API key provided. Unable to fetch explanation.
#
# Index: 11820, Impact: 11.2475, Component Norm: 11.2475
# Explanation: Feature 11820: No API key provided. Unable to fetch explanation.
#
# Index: 14043, Impact: 11.0646, Component Norm: 11.0646
# Explanation: Feature 14043: No API key provided. Unable to fetch explanation.
#
# Index: 338, Impact: 11.0395, Component Norm: 11.0395
# Explanation: Feature 338: No API key provided. Unable to fetch explanation.
#
# Index: 7501, Impact: 10.8624, Component Norm: 10.8624
# Explanation: Feature 7501: No API key provided. Unable to fetch explanation.
#
# Index: 7596, Impact: 10.8249, Component Norm: 10.8249
# Explanation: Feature 7596: No API key provided. Unable to fetch explanation.
#
# Index: 2390, Impact: 10.7889, Component Norm: 10.7889
# Explanation: Feature 2390: No API key provided. Unable to fetch explanation.
#
# Index: 6739, Impact: 10.5467, Component Norm: 10.5467
# Explanation: Feature 6739: No API key provided. Unable to fetch explanation.
#
# Index: 11575, Impact: 10.5333, Component Norm: 10.5333
# Explanation: Feature 11575: No API key provided. Unable to fetch explanation.
#
# Index: 5810, Impact: 10.4631, Component Norm: 10.4631
# Explanation: Feature 5810: No API key provided. Unable to fetch explanation.
#
# Index: 4005, Impact: 10.3498, Component Norm: 10.3498
# Explanation: Feature 4005: No API key provided. Unable to fetch explanation.
#
# Index: 2201, Impact: 10.2783, Component Norm: 10.2783
# Explanation: Feature 2201: No API key provided. Unable to fetch explanation.
#
# Index: 8713, Impact: 10.2578, Component Norm: 10.2578
# Explanation: Feature 8713: No API key provided. Unable to fetch explanation.
#
# Index: 13581, Impact: 10.1077, Component Norm: 10.1077
# Explanation: Feature 13581: No API key provided. Unable to fetch explanation.
#
# Index: 9978, Impact: 10.1045, Component Norm: 10.1045
# Explanation: Feature 9978: No API key provided. Unable to fetch explanation.
#
# Index: 13918, Impact: 9.8277, Component Norm: 9.8277
# Explanation: Feature 13918: No API key provided. Unable to fetch explanation.
#
# Index: 4010, Impact: 9.7506, Component Norm: 9.7506
# Explanation: Feature 4010: No API key provided. Unable to fetch explanation.
#
# Index: 1027, Impact: 9.6418, Component Norm: 9.6418
# Explanation: Feature 1027: No API key provided. Unable to fetch explanation.
#
# Index: 10881, Impact: 9.6284, Component Norm: 9.6284
# Explanation: Feature 10881: No API key provided. Unable to fetch explanation.
#
# Index: 2311, Impact: 9.6138, Component Norm: 9.6138
# Explanation: Feature 2311: No API key provided. Unable to fetch explanation.
#
# Index: 14750, Impact: 9.2983, Component Norm: 9.2983
# Explanation: Feature 14750: No API key provided. Unable to fetch explanation.
#
# Index: 8208, Impact: 9.2935, Component Norm: 9.2935
# Explanation: Feature 8208: No API key provided. Unable to fetch explanation.
#
# Index: 13808, Impact: 9.2023, Component Norm: 9.2023
# Explanation: Feature 13808: No API key provided. Unable to fetch explanation.
#
# Index: 13982, Impact: 9.1934, Component Norm: 9.1934
# Explanation: Feature 13982: No API key provided. Unable to fetch explanation.
#
# Index: 9416, Impact: 9.1289, Component Norm: 9.1289
# Explanation: Feature 9416: No API key provided. Unable to fetch explanation.
#
# Index: 6495, Impact: 9.0767, Component Norm: 9.0767
# Explanation: Feature 6495: No API key provided. Unable to fetch explanation.
#
# Index: 13688, Impact: 9.0123, Component Norm: 9.0123
# ...
# Component vector for feature 2043 saved to sae_vector_features/refusal/feature_2043_component_vector.pt
# Component vector for feature 1121 saved to sae_vector_features/refusal/feature_1121_component_vector.pt
# Component vector for feature 11537 saved to sae_vector_features/refusal/feature_11537_component_vector.pt
# Component vector for feature 10559 saved to sae_vector_features/refusal/feature_10559_component_vector.pt
# Component vector for feature 15664 saved to sae_vector_features/refusal/feature_15664_component_vector.pt
# Component vector for feature 14780 saved to sae_vector_features/refusal/feature_14780_component_vector.pt
# Component vector for feature 4640 saved to sae_vector_features/refusal/feature_4640_component_vector.pt
# Component vector for feature 8560 saved to sae_vector_features/refusal/feature_8560_component_vector.pt
# Component vector for feature 12807 saved to sae_vector_features/refusal/feature_12807_component_vector.pt
# Component vector for feature 8761 saved to sae_vector_features/refusal/feature_8761_component_vector.pt
# Component vector for feature 2987 saved to sae_vector_features/refusal/feature_2987_component_vector.pt
# Component vector for feature 9037 saved to sae_vector_features/refusal/feature_9037_component_vector.pt
# Component vector for feature 3145 saved to sae_vector_features/refusal/feature_3145_component_vector.pt
# Component vector for feature 8549 saved to sae_vector_features/refusal/feature_8549_component_vector.pt
# Component vector for feature 3710 saved to sae_vector_features/refusal/feature_3710_component_vector.pt
# Component vector for feature 7939 saved to sae_vector_features/refusal/feature_7939_component_vector.pt
# Component vector for feature 6085 saved to sae_vector_features/refusal/feature_6085_component_vector.pt
# Component vector for feature 11960 saved to sae_vector_features/refusal/feature_11960_component_vector.pt
# Component vector for feature 7244 saved to sae_vector_features/refusal/feature_7244_component_vector.pt
# Component vector for feature 14737 saved to sae_vector_features/refusal/feature_14737_component_vector.pt
# Component vector for feature 5065 saved to sae_vector_features/refusal/feature_5065_component_vector.pt
# Component vector for feature 7580 saved to sae_vector_features/refusal/feature_7580_component_vector.pt
# Component vector for feature 15789 saved to sae_vector_features/refusal/feature_15789_component_vector.pt
# Component vector for feature 692 saved to sae_vector_features/refusal/feature_692_component_vector.pt
# Component vector for feature 12646 saved to sae_vector_features/refusal/feature_12646_component_vector.pt
# Component vector for feature 2342 saved to sae_vector_features/refusal/feature_2342_component_vector.pt
# Component vector for feature 3176 saved to sae_vector_features/refusal/feature_3176_component_vector.pt
# Component vector for feature 9097 saved to sae_vector_features/refusal/feature_9097_component_vector.pt
# Component vector for feature 11735 saved to sae_vector_features/refusal/feature_11735_component_vector.pt
# Component vector for feature 673 saved to sae_vector_features/refusal/feature_673_component_vector.pt
# Component vector for feature 6199 saved to sae_vector_features/refusal/feature_6199_component_vector.pt
# Component vector for feature 16198 saved to sae_vector_features/refusal/feature_16198_component_vector.pt
# Component vector for feature 10903 saved to sae_vector_features/refusal/feature_10903_component_vector.pt
# Component vector for feature 6075 saved to sae_vector_features/refusal/feature_6075_component_vector.pt
# Component vector for feature 2924 saved to sae_vector_features/refusal/feature_2924_component_vector.pt
# Component vector for feature 14797 saved to sae_vector_features/refusal/feature_14797_component_vector.pt
# Component vector for feature 13988 saved to sae_vector_features/refusal/feature_13988_component_vector.pt
# Component vector for feature 11826 saved to sae_vector_features/refusal/feature_11826_component_vector.pt
# Component vector for feature 8656 saved to sae_vector_features/refusal/feature_8656_component_vector.pt
# Component vector for feature 6699 saved to sae_vector_features/refusal/feature_6699_component_vector.pt
# Component vector for feature 7502 saved to sae_vector_features/refusal/feature_7502_component_vector.pt
# Component vector for feature 6551 saved to sae_vector_features/refusal/feature_6551_component_vector.pt
# Component vector for feature 6040 saved to sae_vector_features/refusal/feature_6040_component_vector.pt
# Component vector for feature 14662 saved to sae_vector_features/refusal/feature_14662_component_vector.pt
# Component vector for feature 11599 saved to sae_vector_features/refusal/feature_11599_component_vector.pt
# Component vector for feature 596 saved to sae_vector_features/refusal/feature_596_component_vector.pt
# Component vector for feature 14417 saved to sae_vector_features/refusal/feature_14417_component_vector.pt
# Component vector for feature 16094 saved to sae_vector_features/refusal/feature_16094_component_vector.pt
# Component vector for feature 10077 saved to sae_vector_features/refusal/feature_10077_component_vector.pt
# Component vector for feature 10595 saved to sae_vector_features/refusal/feature_10595_component_vector.pt
# Component vector for feature 5891 saved to sae_vector_features/refusal/feature_5891_component_vector.pt
# Component vector for feature 5598 saved to sae_vector_features/refusal/feature_5598_component_vector.pt
# Component vector for feature 6362 saved to sae_vector_features/refusal/feature_6362_component_vector.pt
# Component vector for feature 1483 saved to sae_vector_features/refusal/feature_1483_component_vector.pt
# Component vector for feature 385 saved to sae_vector_features/refusal/feature_385_component_vector.pt
# Component vector for feature 9311 saved to sae_vector_features/refusal/feature_9311_component_vector.pt
# Component vector for feature 13869 saved to sae_vector_features/refusal/feature_13869_component_vector.pt
# Component vector for feature 12990 saved to sae_vector_features/refusal/feature_12990_component_vector.pt
# Component vector for feature 302 saved to sae_vector_features/refusal/feature_302_component_vector.pt
# Component vector for feature 3286 saved to sae_vector_features/refusal/feature_3286_component_vector.pt
# Component vector for feature 10537 saved to sae_vector_features/refusal/feature_10537_component_vector.pt
# Component vector for feature 12661 saved to sae_vector_features/refusal/feature_12661_component_vector.pt
# Component vector for feature 13795 saved to sae_vector_features/refusal/feature_13795_component_vector.pt
# Component vector for feature 7300 saved to sae_vector_features/refusal/feature_7300_component_vector.pt
# Component vector for feature 11439 saved to sae_vector_features/refusal/feature_11439_component_vector.pt
# Component vector for feature 6855 saved to sae_vector_features/refusal/feature_6855_component_vector.pt
# Component vector for feature 1784 saved to sae_vector_features/refusal/feature_1784_component_vector.pt
# Component vector for feature 664 saved to sae_vector_features/refusal/feature_664_component_vector.pt
# Component vector for feature 15135 saved to sae_vector_features/refusal/feature_15135_component_vector.pt
# Component vector for feature 395 saved to sae_vector_features/refusal/feature_395_component_vector.pt
# Component vector for feature 9603 saved to sae_vector_features/refusal/feature_9603_component_vector.pt
# Component vector for feature 9663 saved to sae_vector_features/refusal/feature_9663_component_vector.pt
# Component vector for feature 4892 saved to sae_vector_features/refusal/feature_4892_component_vector.pt
# Component vector for feature 4185 saved to sae_vector_features/refusal/feature_4185_component_vector.pt
# Component vector for feature 1906 saved to sae_vector_features/refusal/feature_1906_component_vector.pt
# Component vector for feature 16228 saved to sae_vector_features/refusal/feature_16228_component_vector.pt
# Component vector for feature 11961 saved to sae_vector_features/refusal/feature_11961_component_vector.pt
# Component vector for feature 957 saved to sae_vector_features/refusal/feature_957_component_vector.pt
# Component vector for feature 13493 saved to sae_vector_features/refusal/feature_13493_component_vector.pt
# Component vector for feature 3609 saved to sae_vector_features/refusal/feature_3609_component_vector.pt
# Component vector for feature 10981 saved to sae_vector_features/refusal/feature_10981_component_vector.pt
# Component vector for feature 2237 saved to sae_vector_features/refusal/feature_2237_component_vector.pt
# Component vector for feature 7470 saved to sae_vector_features/refusal/feature_7470_component_vector.pt
# Component vector for feature 9406 saved to sae_vector_features/refusal/feature_9406_component_vector.pt
# Component vector for feature 16221 saved to sae_vector_features/refusal/feature_16221_component_vector.pt
# Component vector for feature 6595 saved to sae_vector_features/refusal/feature_6595_component_vector.pt
# Component vector for feature 7628 saved to sae_vector_features/refusal/feature_7628_component_vector.pt
# Component vector for feature 9290 saved to sae_vector_features/refusal/feature_9290_component_vector.pt
# Component vector for feature 14075 saved to sae_vector_features/refusal/feature_14075_component_vector.pt
# Component vector for feature 5232 saved to sae_vector_features/refusal/feature_5232_component_vector.pt
# Component vector for feature 5480 saved to sae_vector_features/refusal/feature_5480_component_vector.pt
# Component vector for feature 12858 saved to sae_vector_features/refusal/feature_12858_component_vector.pt
# Component vector for feature 8936 saved to sae_vector_features/refusal/feature_8936_component_vector.pt
# Component vector for feature 3625 saved to sae_vector_features/refusal/feature_3625_component_vector.pt
# Component vector for feature 7326 saved to sae_vector_features/refusal/feature_7326_component_vector.pt
# Component vector for feature 5392 saved to sae_vector_features/refusal/feature_5392_component_vector.pt
# Component vector for feature 12773 saved to sae_vector_features/refusal/feature_12773_component_vector.pt
# Component vector for feature 10758 saved to sae_vector_features/refusal/feature_10758_component_vector.pt
# Component vector for feature 6022 saved to sae_vector_features/refusal/feature_6022_component_vector.pt
# Component vector for feature 15784 saved to sae_vector_features/refusal/feature_15784_component_vector.pt
# Component vector for feature 8236 saved to sae_vector_features/refusal/feature_8236_component_vector.pt
# Component vector for feature 2097 saved to sae_vector_features/refusal/feature_2097_component_vector.pt
# Component vector for feature 11106 saved to sae_vector_features/refusal/feature_11106_component_vector.pt
# Component vector for feature 9314 saved to sae_vector_features/refusal/feature_9314_component_vector.pt
# Component vector for feature 8120 saved to sae_vector_features/refusal/feature_8120_component_vector.pt
# Component vector for feature 11427 saved to sae_vector_features/refusal/feature_11427_component_vector.pt
# Component vector for feature 138 saved to sae_vector_features/refusal/feature_138_component_vector.pt
# Component vector for feature 2593 saved to sae_vector_features/refusal/feature_2593_component_vector.pt
# Component vector for feature 2401 saved to sae_vector_features/refusal/feature_2401_component_vector.pt
# Component vector for feature 15417 saved to sae_vector_features/refusal/feature_15417_component_vector.pt
# Component vector for feature 6867 saved to sae_vector_features/refusal/feature_6867_component_vector.pt
# Component vector for feature 6933 saved to sae_vector_features/refusal/feature_6933_component_vector.pt
# Component vector for feature 15876 saved to sae_vector_features/refusal/feature_15876_component_vector.pt
# Component vector for feature 3446 saved to sae_vector_features/refusal/feature_3446_component_vector.pt
# Component vector for feature 4367 saved to sae_vector_features/refusal/feature_4367_component_vector.pt
# Component vector for feature 5720 saved to sae_vector_features/refusal/feature_5720_component_vector.pt
# Component vector for feature 15431 saved to sae_vector_features/refusal/feature_15431_component_vector.pt
# Component vector for feature 1878 saved to sae_vector_features/refusal/feature_1878_component_vector.pt
# Component vector for feature 9651 saved to sae_vector_features/refusal/feature_9651_component_vector.pt
# Component vector for feature 3565 saved to sae_vector_features/refusal/feature_3565_component_vector.pt
# Component vector for feature 3913 saved to sae_vector_features/refusal/feature_3913_component_vector.pt
# Component vector for feature 6428 saved to sae_vector_features/refusal/feature_6428_component_vector.pt
# Component vector for feature 15890 saved to sae_vector_features/refusal/feature_15890_component_vector.pt
# Component vector for feature 12362 saved to sae_vector_features/refusal/feature_12362_component_vector.pt
# Component vector for feature 3952 saved to sae_vector_features/refusal/feature_3952_component_vector.pt
# Component vector for feature 13880 saved to sae_vector_features/refusal/feature_13880_component_vector.pt
# Component vector for feature 1980 saved to sae_vector_features/refusal/feature_1980_component_vector.pt
# Component vector for feature 7507 saved to sae_vector_features/refusal/feature_7507_component_vector.pt
# Component vector for feature 13083 saved to sae_vector_features/refusal/feature_13083_component_vector.pt
# Component vector for feature 325 saved to sae_vector_features/refusal/feature_325_component_vector.pt
# Component vector for feature 7017 saved to sae_vector_features/refusal/feature_7017_component_vector.pt
# Component vector for feature 8559 saved to sae_vector_features/refusal/feature_8559_component_vector.pt
# Component vector for feature 10449 saved to sae_vector_features/refusal/feature_10449_component_vector.pt
# Component vector for feature 778 saved to sae_vector_features/refusal/feature_778_component_vector.pt
# Component vector for feature 10509 saved to sae_vector_features/refusal/feature_10509_component_vector.pt
# Component vector for feature 13241 saved to sae_vector_features/refusal/feature_13241_component_vector.pt
# Component vector for feature 14461 saved to sae_vector_features/refusal/feature_14461_component_vector.pt
# Component vector for feature 1110 saved to sae_vector_features/refusal/feature_1110_component_vector.pt
# Component vector for feature 3685 saved to sae_vector_features/refusal/feature_3685_component_vector.pt
# Component vector for feature 9247 saved to sae_vector_features/refusal/feature_9247_component_vector.pt
# Component vector for feature 6067 saved to sae_vector_features/refusal/feature_6067_component_vector.pt
# Component vector for feature 15109 saved to sae_vector_features/refusal/feature_15109_component_vector.pt
# Component vector for feature 8642 saved to sae_vector_features/refusal/feature_8642_component_vector.pt
# Component vector for feature 5903 saved to sae_vector_features/refusal/feature_5903_component_vector.pt
# Component vector for feature 5990 saved to sae_vector_features/refusal/feature_5990_component_vector.pt
# Component vector for feature 16210 saved to sae_vector_features/refusal/feature_16210_component_vector.pt
# Component vector for feature 9735 saved to sae_vector_features/refusal/feature_9735_component_vector.pt
# Component vector for feature 14336 saved to sae_vector_features/refusal/feature_14336_component_vector.pt
# Component vector for feature 12384 saved to sae_vector_features/refusal/feature_12384_component_vector.pt
# Component vector for feature 933 saved to sae_vector_features/refusal/feature_933_component_vector.pt
# Component vector for feature 3903 saved to sae_vector_features/refusal/feature_3903_component_vector.pt
# Top k feature explanations and component vectors by impact saved to sae_vector_features/refusal/top_364_features_explanations_refusal.pt

# %%
import torch
import os
from torch.linalg import svd

# Load the saved data
sae_vector_dir = "sae_vector_features/refusal"
saved_data_path = os.path.join(sae_vector_dir, "top_364_features_explanations_refusal.pt")
top_features_with_explanations = torch.load(saved_data_path)

# Extract component vectors and stack them into a matrix
component_vectors = [component_vector for _, _, _, component_vector, _ in top_features_with_explanations]
matrix = torch.stack(component_vectors)

# Perform SVD
U, S, V = svd(matrix)

# Print shapes of resulting matrices
print(f"Shape of U: {U.shape}")
print(f"Shape of S: {S.shape}")
print(f"Shape of V: {V.shape}")

# Print the top 10 singular values
print("Top 10 singular values:")
print(S[:10])

# Calculate the explained variance ratio
total_variance = (S**2).sum()
explained_variance_ratio = (S**2) / total_variance

# Calculate and print the cumulative explained variance for the top 10 components
cumulative_variance = explained_variance_ratio.cumsum(dim=0)
print("\nCumulative explained variance ratio for top 10 components:")
print(cumulative_variance[:10])

# Calculate total explained variance by all components
total_explained_variance = cumulative_variance[-1].item()
print(f"\nTotal explained variance: {total_explained_variance:.4f}")

# Find number of components needed to explain 95% of variance
components_95 = torch.where(cumulative_variance > 0.95)[0][0].item() + 1
print(f"\nNumber of components needed to explain 95% of variance: {components_95}")

# Save the SVD results
torch.save({
    'U': U.cpu(),
    'S': S.cpu(),
    'V': V.cpu(),
    'explained_variance_ratio': explained_variance_ratio.cpu()
}, os.path.join(sae_vector_dir, "refusal_vectors_svd_results.pt"))

print("\nSVD results saved to refusal_vectors_svd_results.pt")
# Out:
# Shape of U: torch.Size([364, 364])
# Shape of S: torch.Size([364])
# Shape of V: torch.Size([2304, 2304])
# Top 10 singular values:
# tensor([34.0036, 28.4630, 28.1067, 26.2105, 24.6611, 20.8591, 20.2428, 19.1884,
#         18.3579, 17.8608], device='cuda:0', grad_fn=<SliceBackward0>)
#
# Cumulative explained variance ratio for top 10 components:
# tensor([0.0512, 0.0871, 0.1221, 0.1525, 0.1794, 0.1987, 0.2168, 0.2331, 0.2481,
#         0.2622], device='cuda:0', grad_fn=<SliceBackward0>)
#
# Total explained variance: 1.0000
#
# Number of components needed to explain 95% of variance: 267
#
# SVD results saved to refusal_vectors_svd_results.pt

# %%
import torch
import os
import matplotlib.pyplot as plt

# Load the full SVD results
sae_vector_dir = "sae_vector_features/refusal"
svd_results = torch.load(os.path.join(sae_vector_dir, "refusal_vectors_svd_results.pt"))
S = svd_results['S'].detach()  # Detach here

# Calculate the explained variance ratio
total_variance = (S**2).sum()
explained_variance_ratio = (S**2) / total_variance

# Calculate cumulative explained variance
cumulative_variance = explained_variance_ratio.cumsum(dim=0)

# Find number of components needed to explain 95% of variance
components_95 = torch.where(cumulative_variance > 0.95)[0][0].item() + 1
print(f"\nNumber of components needed to explain 95% of variance: {components_95}")

# Plot singular value distribution
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(S) + 1), S.cpu().numpy())  # Use cpu() before numpy()
plt.title('Singular Value Distribution of SAE Features')
plt.xlabel('Component')
plt.ylabel('Singular Value')
plt.yscale('log')
plt.grid(True)
plt.savefig(os.path.join(sae_vector_dir, 'sae_features_singular_values_full.png'))
plt.close()

# Plot cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance.cpu().numpy())  # Use cpu() before numpy()
plt.title('Cumulative Explained Variance Ratio of SAE Features')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.grid(True)
plt.savefig(os.path.join(sae_vector_dir, 'sae_features_cumulative_variance_full.png'))
plt.close()

print("\nPlots saved with full data in the sae_vector_dir")

# Print the top 20 explained variance ratios
print("\nTop 20 explained variance ratios:")
print(explained_variance_ratio[:20].cpu().numpy())

# Print total number of components
print(f"\nTotal number of components: {len(S)}")

# Print cumulative explained variance at specific points
print(f"\nCumulative explained variance at 10 components: {cumulative_variance[9].item():.4f}")
print(f"Cumulative explained variance at 50 components: {cumulative_variance[49].item():.4f}")
print(f"Cumulative explained variance at 100 components: {cumulative_variance[99].item():.4f}")
print(f"Cumulative explained variance at 200 components: {cumulative_variance[199].item():.4f}")
# Out:
# Number of components needed to explain 95% of variance: 267
#
# Plots saved with full data in the sae_vector_dir
#
# Top 20 explained variance ratios:
# [0.0512042  0.03587701 0.03498433 0.03042324 0.02693271 0.01926847
#  0.01814655 0.01630548 0.01492461 0.01412715 0.01358052 0.01294222
#  0.01235004 0.0118709  0.0112854  0.01082568 0.010089   0.00981603
#  0.0093365  0.00899045]
#
# Total number of components: 364
#
# Cumulative explained variance at 10 components: 0.2622
# Cumulative explained variance at 50 components: 0.5611
# Cumulative explained variance at 100 components: 0.7240
# Cumulative explained variance at 200 components: 0.8889

# %%
import torch
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the saved data
sae_vector_dir = "sae_vector_features/refusal"
saved_data_path = os.path.join(sae_vector_dir, "top_364_features_explanations_refusal.pt")
top_features_with_explanations = torch.load(saved_data_path)

# Extract the component vectors (SAE features)
sae_features = torch.stack([component_vector for _, _, _, component_vector, _ in top_features_with_explanations])

# Normalize the features
sae_features_normalized = sae_features / torch.norm(sae_features, dim=1, keepdim=True)

# Compute the similarity matrix (dot products)
similarity_matrix = torch.mm(sae_features_normalized, sae_features_normalized.t())

# Convert to numpy for easier analysis
similarity_matrix_np = similarity_matrix.detach().cpu().numpy()  # Added detach() here

# Compute statistics
np.fill_diagonal(similarity_matrix_np, 0)  # Exclude self-similarity
mean_similarity = np.mean(similarity_matrix_np)
median_similarity = np.median(similarity_matrix_np)
max_similarity = np.max(similarity_matrix_np)
min_similarity = np.min(similarity_matrix_np)
std_similarity = np.std(similarity_matrix_np)

print(f"Mean similarity: {mean_similarity:.4f}")
print(f"Median similarity: {median_similarity:.4f}")
print(f"Max similarity: {max_similarity:.4f}")
print(f"Min similarity: {min_similarity:.4f}")
print(f"Standard deviation of similarity: {std_similarity:.4f}")

# Plot histogram of similarities
plt.figure(figsize=(10, 6))
plt.hist(similarity_matrix_np.flatten(), bins=50)
plt.title("Distribution of SAE Feature Similarities")
plt.xlabel("Cosine Similarity")
plt.ylabel("Frequency")
plt.savefig(os.path.join(sae_vector_dir, 'sae_features_similarity_histogram.png'))
plt.close()

# Plot heatmap of similarities
plt.figure(figsize=(12, 10))
sns.heatmap(similarity_matrix_np, cmap='viridis', xticklabels=False, yticklabels=False)
plt.title("Heatmap of SAE Feature Similarities")
plt.savefig(os.path.join(sae_vector_dir, 'sae_features_similarity_heatmap.png'))
plt.close()

# Find top 10 most similar pairs
np.fill_diagonal(similarity_matrix_np, -1)  # Exclude self-similarity
top_10_indices = np.argpartition(similarity_matrix_np.flatten(), -10)[-10:]
top_10_similarities = similarity_matrix_np.flatten()[top_10_indices]
top_10_pairs = np.unravel_index(top_10_indices, similarity_matrix_np.shape)

print("\nTop 10 most similar pairs of features:")
for i in range(10):
    print(f"Features {top_10_pairs[0][i]} and {top_10_pairs[1][i]}: Similarity = {top_10_similarities[i]:.4f}")

print("\nAnalysis complete. Plots saved in the sae_vector_dir.")
# Out:
# Mean similarity: 0.0059
# Median similarity: 0.0028
# Max similarity: 0.3696
# Min similarity: -0.2462
# Standard deviation of similarity: 0.0302
#
# Top 10 most similar pairs of features:
# Features 354 and 331: Similarity = 0.2943
# Features 331 and 354: Similarity = 0.2943
# Features 148 and 348: Similarity = 0.2991
# Features 348 and 148: Similarity = 0.2991
# Features 77 and 90: Similarity = 0.3024
# Features 90 and 77: Similarity = 0.3024
# Features 344 and 9: Similarity = 0.3263
# Features 159 and 88: Similarity = 0.3696
# Features 88 and 159: Similarity = 0.3696
# Features 9 and 344: Similarity = 0.3263
#
# Analysis complete. Plots saved in the sae_vector_dir.

# %%
#SCREE PLOT

import matplotlib.pyplot as plt

# Extract impact values
impacts_sorted = [impact for index, impact, explanation, component_vector, component_norm in top_features_with_explanations]

# Create scree plot
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(impacts_sorted) + 1), impacts_sorted, marker='o', linestyle='-', color='b')
plt.title('Scree Plot: Feature Impacts')
plt.xlabel('Feature Rank')
plt.ylabel('Impact')
plt.grid(True)
plt.show()


from sklearn.cluster import KMeans
import numpy as np

# Collect component vectors into a matrix
component_vectors_matrix = torch.stack([component_vector for _, _, _, component_vector, _ in top_features_with_explanations])

# Detach the tensor from the computation graph and convert it to NumPy
component_vectors_matrix = component_vectors_matrix.detach().cpu().numpy()

# Apply K-means clustering
num_clusters = 100  # Choose the number of clusters (adjust as needed)
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(component_vectors_matrix)

# Get cluster labels
cluster_labels = kmeans.labels_

# Print cluster assignments
for i, (index, impact, explanation, component_vector, component_norm) in enumerate(top_features_with_explanations):
    print(f"Feature {index}: Cluster {cluster_labels[i]}, Impact: {impact:.4f}, Explanation: {explanation}")



from sklearn.manifold import TSNE
import seaborn as sns

# Reduce dimensions with t-SNE
tsne = TSNE(n_components=2, random_state=42)
component_vectors_2d = tsne.fit_transform(component_vectors_matrix)

# Plot clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=component_vectors_2d[:, 0], y=component_vectors_2d[:, 1], hue=cluster_labels, palette='viridis')
plt.title("t-SNE Visualization of Feature Clusters")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.show()
# Out:
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#
# Feature 1391: Cluster 24, Impact: 6.7931, Explanation: Feature 1391: No API key provided. Unable to fetch explanation.
# Feature 15985: Cluster 46, Impact: 6.7906, Explanation: Feature 15985: No API key provided. Unable to fetch explanation.
# Feature 13068: Cluster 75, Impact: 6.7818, Explanation: Feature 13068: No API key provided. Unable to fetch explanation.
# Feature 12957: Cluster 24, Impact: 6.7606, Explanation: Feature 12957: No API key provided. Unable to fetch explanation.
# Feature 8608: Cluster 34, Impact: 6.7128, Explanation: Feature 8608: No API key provided. Unable to fetch explanation.
# Feature 10842: Cluster 76, Impact: 6.7030, Explanation: Feature 10842: No API key provided. Unable to fetch explanation.
# Feature 1957: Cluster 34, Impact: 6.7019, Explanation: Feature 1957: No API key provided. Unable to fetch explanation.
# Feature 6273: Cluster 46, Impact: 6.6658, Explanation: Feature 6273: No API key provided. Unable to fetch explanation.
# Feature 13382: Cluster 75, Impact: 6.6605, Explanation: Feature 13382: No API key provided. Unable to fetch explanation.
# Feature 9806: Cluster 96, Impact: 6.6530, Explanation: Feature 9806: No API key provided. Unable to fetch explanation.
# Feature 16008: Cluster 4, Impact: 6.6129, Explanation: Feature 16008: No API key provided. Unable to fetch explanation.
# Feature 5823: Cluster 4, Impact: 6.6028, Explanation: Feature 5823: No API key provided. Unable to fetch explanation.
# Feature 2375: Cluster 94, Impact: 6.5503, Explanation: Feature 2375: No API key provided. Unable to fetch explanation.
# Feature 329: Cluster 46, Impact: 6.5175, Explanation: Feature 329: No API key provided. Unable to fetch explanation.
# Feature 7425: Cluster 43, Impact: 6.5033, Explanation: Feature 7425: No API key provided. Unable to fetch explanation.
# Feature 8431: Cluster 46, Impact: 6.4959, Explanation: Feature 8431: No API key provided. Unable to fetch explanation.
# Feature 965: Cluster 4, Impact: 6.4764, Explanation: Feature 965: No API key provided. Unable to fetch explanation.
# Feature 11187: Cluster 46, Impact: 6.4587, Explanation: Feature 11187: No API key provided. Unable to fetch explanation.
# Feature 3621: Cluster 24, Impact: 6.4491, Explanation: Feature 3621: No API key provided. Unable to fetch explanation.
# Feature 10504: Cluster 24, Impact: 6.4411, Explanation: Feature 10504: No API key provided. Unable to fetch explanation.
# Feature 1909: Cluster 24, Impact: 6.4282, Explanation: Feature 1909: No API key provided. Unable to fetch explanation.
# Feature 413: Cluster 34, Impact: 6.3920, Explanation: Feature 413: No API key provided. Unable to fetch explanation.
# Feature 1698: Cluster 46, Impact: 6.3882, Explanation: Feature 1698: No API key provided. Unable to fetch explanation.
# Feature 11065: Cluster 4, Impact: 6.3546, Explanation: Feature 11065: No API key provided. Unable to fetch explanation.
# Feature 16022: Cluster 75, Impact: 6.3280, Explanation: Feature 16022: No API key provided. Unable to fetch explanation.
# Feature 5763: Cluster 34, Impact: 6.3179, Explanation: Feature 5763: No API key provided. Unable to fetch explanation.
# Feature 391: Cluster 24, Impact: 6.2922, Explanation: Feature 391: No API key provided. Unable to fetch explanation.
# Feature 13659: Cluster 46, Impact: 6.2910, Explanation: Feature 13659: No API key provided. Unable to fetch explanation.
# Feature 8984: Cluster 34, Impact: 6.2808, Explanation: Feature 8984: No API key provided. Unable to fetch explanation.
# Feature 6376: Cluster 4, Impact: 6.2570, Explanation: Feature 6376: No API key provided. Unable to fetch explanation.
# Feature 9681: Cluster 46, Impact: 6.2460, Explanation: Feature 9681: No API key provided. Unable to fetch explanation.
# Feature 16059: Cluster 75, Impact: 6.2371, Explanation: Feature 16059: No API key provided. Unable to fetch explanation.
# Feature 13036: Cluster 75, Impact: 6.2156, Explanation: Feature 13036: No API key provided. Unable to fetch explanation.
# Feature 16297: Cluster 75, Impact: 6.2081, Explanation: Feature 16297: No API key provided. Unable to fetch explanation.
# Feature 1681: Cluster 46, Impact: 6.1908, Explanation: Feature 1681: No API key provided. Unable to fetch explanation.
# Feature 12685: Cluster 76, Impact: 6.1594, Explanation: Feature 12685: No API key provided. Unable to fetch explanation.
# Feature 14646: Cluster 4, Impact: 6.1553, Explanation: Feature 14646: No API key provided. Unable to fetch explanation.
# Feature 731: Cluster 4, Impact: 6.1469, Explanation: Feature 731: No API key provided. Unable to fetch explanation.
# Feature 5060: Cluster 24, Impact: 6.0864, Explanation: Feature 5060: No API key provided. Unable to fetch explanation.
# Feature 9145: Cluster 75, Impact: 6.0860, Explanation: Feature 9145: No API key provided. Unable to fetch explanation.
# Feature 13312: Cluster 75, Impact: 6.0641, Explanation: Feature 13312: No API key provided. Unable to fetch explanation.
# Feature 15304: Cluster 75, Impact: 6.0625, Explanation: Feature 15304: No API key provided. Unable to fetch explanation.
# Feature 9767: Cluster 4, Impact: 6.0551, Explanation: Feature 9767: No API key provided. Unable to fetch explanation.
# Feature 7443: Cluster 75, Impact: 6.0000, Explanation: Feature 7443: No API key provided. Unable to fetch explanation.
# Feature 14120: Cluster 45, Impact: 5.9998, Explanation: Feature 14120: No API key provided. Unable to fetch explanation.
# Feature 4381: Cluster 4, Impact: 5.9972, Explanation: Feature 4381: No API key provided. Unable to fetch explanation.
# Feature 3703: Cluster 4, Impact: 5.9525, Explanation: Feature 3703: No API key provided. Unable to fetch explanation.
# Feature 6992: Cluster 24, Impact: 5.9278, Explanation: Feature 6992: No API key provided. Unable to fetch explanation.
# Feature 3030: Cluster 46, Impact: 5.9276, Explanation: Feature 3030: No API key provided. Unable to fetch explanation.
# Feature 1109: Cluster 34, Impact: 5.8943, Explanation: Feature 1109: No API key provided. Unable to fetch explanation.
# Feature 15753: Cluster 4, Impact: 5.8891, Explanation: Feature 15753: No API key provided. Unable to fetch explanation.
# Feature 6197: Cluster 75, Impact: 5.8676, Explanation: Feature 6197: No API key provided. Unable to fetch explanation.
# Feature 5776: Cluster 4, Impact: 5.8619, Explanation: Feature 5776: No API key provided. Unable to fetch explanation.
# Feature 12746: Cluster 75, Impact: 5.8511, Explanation: Feature 12746: No API key provided. Unable to fetch explanation.
# Feature 4158: Cluster 24, Impact: 5.8406, Explanation: Feature 4158: No API key provided. Unable to fetch explanation.
# Feature 1139: Cluster 24, Impact: 5.8127, Explanation: Feature 1139: No API key provided. Unable to fetch explanation.
# Feature 7082: Cluster 46, Impact: 5.7678, Explanation: Feature 7082: No API key provided. Unable to fetch explanation.
# Feature 12335: Cluster 75, Impact: 5.7547, Explanation: Feature 12335: No API key provided. Unable to fetch explanation.
# Feature 4378: Cluster 4, Impact: 5.7084, Explanation: Feature 4378: No API key provided. Unable to fetch explanation.
# Feature 9128: Cluster 46, Impact: 5.6912, Explanation: Feature 9128: No API key provided. Unable to fetch explanation.
# Feature 4092: Cluster 75, Impact: 5.6889, Explanation: Feature 4092: No API key provided. Unable to fetch explanation.
# Feature 8449: Cluster 76, Impact: 5.6503, Explanation: Feature 8449: No API key provided. Unable to fetch explanation.
# Feature 3931: Cluster 24, Impact: 5.6346, Explanation: Feature 3931: No API key provided. Unable to fetch explanation.
# Feature 5273: Cluster 24, Impact: 5.6255, Explanation: Feature 5273: No API key provided. Unable to fetch explanation.
# Feature 2024: Cluster 75, Impact: 5.5975, Explanation: Feature 2024: No API key provided. Unable to fetch explanation.
# Feature 3377: Cluster 24, Impact: 5.5800, Explanation: Feature 3377: No API key provided. Unable to fetch explanation.
# Feature 6398: Cluster 79, Impact: 5.5741, Explanation: Feature 6398: No API key provided. Unable to fetch explanation.
# Feature 5194: Cluster 4, Impact: 5.5521, Explanation: Feature 5194: No API key provided. Unable to fetch explanation.
# Feature 7348: Cluster 75, Impact: 5.5383, Explanation: Feature 7348: No API key provided. Unable to fetch explanation.
# Feature 8155: Cluster 4, Impact: 5.5379, Explanation: Feature 8155: No API key provided. Unable to fetch explanation.
# Feature 4394: Cluster 34, Impact: 5.5306, Explanation: Feature 4394: No API key provided. Unable to fetch explanation.
# Feature 4002: Cluster 76, Impact: 5.4923, Explanation: Feature 4002: No API key provided. Unable to fetch explanation.
# Feature 6088: Cluster 24, Impact: 5.4754, Explanation: Feature 6088: No API key provided. Unable to fetch explanation.
# Feature 1010: Cluster 75, Impact: 5.4503, Explanation: Feature 1010: No API key provided. Unable to fetch explanation.
# Feature 9354: Cluster 24, Impact: 5.4470, Explanation: Feature 9354: No API key provided. Unable to fetch explanation.
# Feature 11238: Cluster 4, Impact: 5.4465, Explanation: Feature 11238: No API key provided. Unable to fetch explanation.
# Feature 10849: Cluster 24, Impact: 5.4463, Explanation: Feature 10849: No API key provided. Unable to fetch explanation.
# Feature 4900: Cluster 4, Impact: 5.4305, Explanation: Feature 4900: No API key provided. Unable to fetch explanation.
# Feature 3862: Cluster 34, Impact: 5.4266, Explanation: Feature 3862: No API key provided. Unable to fetch explanation.
# Feature 3629: Cluster 46, Impact: 5.4154, Explanation: Feature 3629: No API key provided. Unable to fetch explanation.
# Feature 5475: Cluster 4, Impact: 5.4087, Explanation: Feature 5475: No API key provided. Unable to fetch explanation.
# Feature 9005: Cluster 75, Impact: 5.4049, Explanation: Feature 9005: No API key provided. Unable to fetch explanation.
# Feature 7773: Cluster 76, Impact: 5.3990, Explanation: Feature 7773: No API key provided. Unable to fetch explanation.
# Feature 14223: Cluster 4, Impact: 5.3859, Explanation: Feature 14223: No API key provided. Unable to fetch explanation.
# Feature 5984: Cluster 75, Impact: 5.3859, Explanation: Feature 5984: No API key provided. Unable to fetch explanation.
# Feature 9981: Cluster 34, Impact: 5.3758, Explanation: Feature 9981: No API key provided. Unable to fetch explanation.
# Feature 14816: Cluster 76, Impact: 5.3618, Explanation: Feature 14816: No API key provided. Unable to fetch explanation.
# Feature 649: Cluster 34, Impact: 5.3586, Explanation: Feature 649: No API key provided. Unable to fetch explanation.
# Feature 10459: Cluster 46, Impact: 5.3426, Explanation: Feature 10459: No API key provided. Unable to fetch explanation.
# Feature 9901: Cluster 4, Impact: 5.3294, Explanation: Feature 9901: No API key provided. Unable to fetch explanation.
# Feature 9548: Cluster 46, Impact: 5.3166, Explanation: Feature 9548: No API key provided. Unable to fetch explanation.
# Feature 12942: Cluster 24, Impact: 5.3151, Explanation: Feature 12942: No API key provided. Unable to fetch explanation.
# Feature 9947: Cluster 46, Impact: 5.3089, Explanation: Feature 9947: No API key provided. Unable to fetch explanation.
# Feature 13424: Cluster 46, Impact: 5.2813, Explanation: Feature 13424: No API key provided. Unable to fetch explanation.
# Feature 12716: Cluster 4, Impact: 5.2798, Explanation: Feature 12716: No API key provided. Unable to fetch explanation.
# Feature 3902: Cluster 24, Impact: 5.2754, Explanation: Feature 3902: No API key provided. Unable to fetch explanation.
# Feature 1213: Cluster 75, Impact: 5.2393, Explanation: Feature 1213: No API key provided. Unable to fetch explanation.
# Feature 8969: Cluster 75, Impact: 5.2378, Explanation: Feature 8969: No API key provided. Unable to fetch explanation.
# Feature 2043: Cluster 75, Impact: 5.2126, Explanation: Feature 2043: No API key provided. Unable to fetch explanation.
# Feature 1121: Cluster 75, Impact: 5.2048, Explanation: Feature 1121: No API key provided. Unable to fetch explanation.
# Feature 11537: Cluster 46, Impact: 5.1763, Explanation: Feature 11537: No API key provided. Unable to fetch explanation.
# Feature 10559: Cluster 75, Impact: 5.1575, Explanation: Feature 10559: No API key provided. Unable to fetch explanation.
# Feature 15664: Cluster 46, Impact: 5.1497, Explanation: Feature 15664: No API key provided. Unable to fetch explanation.
# Feature 14780: Cluster 75, Impact: 5.1293, Explanation: Feature 14780: No API key provided. Unable to fetch explanation.
# Feature 4640: Cluster 75, Impact: 5.1212, Explanation: Feature 4640: No API key provided. Unable to fetch explanation.
# Feature 8560: Cluster 4, Impact: 5.1186, Explanation: Feature 8560: No API key provided. Unable to fetch explanation.
# Feature 12807: Cluster 4, Impact: 5.1168, Explanation: Feature 12807: No API key provided. Unable to fetch explanation.
# Feature 8761: Cluster 24, Impact: 5.1074, Explanation: Feature 8761: No API key provided. Unable to fetch explanation.
# Feature 2987: Cluster 34, Impact: 5.0669, Explanation: Feature 2987: No API key provided. Unable to fetch explanation.
# Feature 9037: Cluster 76, Impact: 5.0585, Explanation: Feature 9037: No API key provided. Unable to fetch explanation.
# Feature 3145: Cluster 75, Impact: 5.0574, Explanation: Feature 3145: No API key provided. Unable to fetch explanation.
# Feature 8549: Cluster 34, Impact: 5.0546, Explanation: Feature 8549: No API key provided. Unable to fetch explanation.
# Feature 3710: Cluster 46, Impact: 5.0515, Explanation: Feature 3710: No API key provided. Unable to fetch explanation.
# Feature 11599: Cluster 75, Impact: 4.6900, Explanation: Feature 11599: No API key provided. Unable to fetch explanation.
# Feature 596: Cluster 76, Impact: 4.6874, Explanation: Feature 596: No API key provided. Unable to fetch explanation.
# Feature 14417: Cluster 4, Impact: 4.6794, Explanation: Feature 14417: No API key provided. Unable to fetch explanation.
# Feature 16094: Cluster 34, Impact: 4.6668, Explanation: Feature 16094: No API key provided. Unable to fetch explanation.
# Feature 10077: Cluster 4, Impact: 4.6571, Explanation: Feature 10077: No API key provided. Unable to fetch explanation.
# Feature 10595: Cluster 75, Impact: 4.6557, Explanation: Feature 10595: No API key provided. Unable to fetch explanation.
# Feature 5891: Cluster 75, Impact: 4.6399, Explanation: Feature 5891: No API key provided. Unable to fetch explanation.
# Feature 5598: Cluster 24, Impact: 4.6295, Explanation: Feature 5598: No API key provided. Unable to fetch explanation.
# Feature 6362: Cluster 24, Impact: 4.6275, Explanation: Feature 6362: No API key provided. Unable to fetch explanation.
# Feature 1483: Cluster 75, Impact: 4.6251, Explanation: Feature 1483: No API key provided. Unable to fetch explanation.
# Feature 385: Cluster 75, Impact: 4.6227, Explanation: Feature 385: No API key provided. Unable to fetch explanation.
# Feature 9311: Cluster 4, Impact: 4.6212, Explanation: Feature 9311: No API key provided. Unable to fetch explanation.
# Feature 13869: Cluster 76, Impact: 4.6142, Explanation: Feature 13869: No API key provided. Unable to fetch explanation.
# Feature 12990: Cluster 46, Impact: 4.6127, Explanation: Feature 12990: No API key provided. Unable to fetch explanation.
# Feature 302: Cluster 75, Impact: 4.6123, Explanation: Feature 302: No API key provided. Unable to fetch explanation.
# Feature 3286: Cluster 46, Impact: 4.6061, Explanation: Feature 3286: No API key provided. Unable to fetch explanation.
# Feature 10537: Cluster 75, Impact: 4.5787, Explanation: Feature 10537: No API key provided. Unable to fetch explanation.
# Feature 12661: Cluster 75, Impact: 4.5747, Explanation: Feature 12661: No API key provided. Unable to fetch explanation.
# Feature 13795: Cluster 46, Impact: 4.5674, Explanation: Feature 13795: No API key provided. Unable to fetch explanation.
# Feature 7300: Cluster 75, Impact: 4.5576, Explanation: Feature 7300: No API key provided. Unable to fetch explanation.
# Feature 11439: Cluster 24, Impact: 4.5564, Explanation: Feature 11439: No API key provided. Unable to fetch explanation.
# Feature 6855: Cluster 76, Impact: 4.5560, Explanation: Feature 6855: No API key provided. Unable to fetch explanation.
# Feature 1784: Cluster 24, Impact: 4.5546, Explanation: Feature 1784: No API key provided. Unable to fetch explanation.
# Feature 664: Cluster 75, Impact: 4.5201, Explanation: Feature 664: No API key provided. Unable to fetch explanation.
# Feature 15135: Cluster 75, Impact: 4.5075, Explanation: Feature 15135: No API key provided. Unable to fetch explanation.
# Feature 395: Cluster 75, Impact: 4.5064, Explanation: Feature 395: No API key provided. Unable to fetch explanation.
# Feature 9603: Cluster 34, Impact: 4.5033, Explanation: Feature 9603: No API key provided. Unable to fetch explanation.
# Feature 9663: Cluster 4, Impact: 4.5028, Explanation: Feature 9663: No API key provided. Unable to fetch explanation.
# Feature 13083: Cluster 46, Impact: 4.0511, Explanation: Feature 13083: No API key provided. Unable to fetch explanation.
# Feature 325: Cluster 75, Impact: 4.0371, Explanation: Feature 325: No API key provided. Unable to fetch explanation.
# Feature 7017: Cluster 4, Impact: 4.0262, Explanation: Feature 7017: No API key provided. Unable to fetch explanation.
# Feature 8559: Cluster 76, Impact: 4.0078, Explanation: Feature 8559: No API key provided. Unable to fetch explanation.
# Feature 10449: Cluster 34, Impact: 4.0065, Explanation: Feature 10449: No API key provided. Unable to fetch explanation.
# Feature 778: Cluster 24, Impact: 4.0010, Explanation: Feature 778: No API key provided. Unable to fetch explanation.
# Feature 10509: Cluster 76, Impact: 3.9815, Explanation: Feature 10509: No API key provided. Unable to fetch explanation.
# Feature 13241: Cluster 75, Impact: 3.9725, Explanation: Feature 13241: No API key provided. Unable to fetch explanation.
# Feature 14461: Cluster 4, Impact: 3.9690, Explanation: Feature 14461: No API key provided. Unable to fetch explanation.
# Feature 1110: Cluster 75, Impact: 3.9429, Explanation: Feature 1110: No API key provided. Unable to fetch explanation.
# Feature 3685: Cluster 76, Impact: 3.9399, Explanation: Feature 3685: No API key provided. Unable to fetch explanation.
# Feature 9247: Cluster 4, Impact: 3.9348, Explanation: Feature 9247: No API key provided. Unable to fetch explanation.
# Feature 6067: Cluster 24, Impact: 3.9307, Explanation: Feature 6067: No API key provided. Unable to fetch explanation.
# Feature 15109: Cluster 75, Impact: 3.9294, Explanation: Feature 15109: No API key provided. Unable to fetch explanation.
# Feature 8642: Cluster 46, Impact: 3.9244, Explanation: Feature 8642: No API key provided. Unable to fetch explanation.
# Feature 5903: Cluster 75, Impact: 3.9120, Explanation: Feature 5903: No API key provided. Unable to fetch explanation.
# Feature 5990: Cluster 24, Impact: 3.9110, Explanation: Feature 5990: No API key provided. Unable to fetch explanation.
# Feature 16210: Cluster 75, Impact: 3.8900, Explanation: Feature 16210: No API key provided. Unable to fetch explanation.
# Feature 9735: Cluster 4, Impact: 3.8818, Explanation: Feature 9735: No API key provided. Unable to fetch explanation.
# Feature 14336: Cluster 4, Impact: 3.8814, Explanation: Feature 14336: No API key provided. Unable to fetch explanation.
# Feature 12384: Cluster 75, Impact: 3.8725, Explanation: Feature 12384: No API key provided. Unable to fetch explanation.
# Feature 933: Cluster 75, Impact: 3.8723, Explanation: Feature 933: No API key provided. Unable to fetch explanation.
# Feature 3903: Cluster 76, Impact: 3.8658, Explanation: Feature 3903: No API key provided. Unable to fetch explanation.

# %%
#SCREE 2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# Elbow Method to find the optimal number of clusters
def elbow_method(component_vectors_matrix, max_clusters=100):
    distortions = []
    K = range(1, max_clusters + 1)
    
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(component_vectors_matrix)
        distortions.append(kmeans.inertia_)  # Sum of squared distances to nearest cluster center
    
    # Plot the elbow graph
    plt.figure(figsize=(8, 5))
    plt.plot(K, distortions, 'bx-')
    plt.xlabel('Number of clusters (k)')
    plt.ylabel('Distortion (Inertia)')
    plt.title('Elbow Method: Optimal Number of Clusters')
    plt.grid(True)
    plt.show()

# Silhouette Score for evaluating clustering performance
def silhouette_analysis(component_vectors_matrix, max_clusters=10):
    silhouette_scores = []
    K = range(2, max_clusters + 1)
    
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42)
        cluster_labels = kmeans.fit_predict(component_vectors_matrix)
        silhouette_avg = silhouette_score(component_vectors_matrix, cluster_labels)
        silhouette_scores.append(silhouette_avg)
    
    # Plot silhouette scores
    plt.figure(figsize=(8, 5))
    plt.plot(K, silhouette_scores, 'bx-')
    plt.xlabel('Number of clusters (k)')
    plt.ylabel('Silhouette Score')
    plt.title('Silhouette Scores: Optimal Number of Clusters')
    plt.grid(True)
    plt.show()

# Assuming component_vectors_matrix is your NumPy matrix of component vectors
elbow_method(component_vectors_matrix, max_clusters=10)
silhouette_analysis(component_vectors_matrix, max_clusters=10)
# Out:
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /root/CAA/venv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
#SCREE 3

# Extract (index, impact) tuples instead of just impact
impacts_sorted = [(index, impact) for index, impact, _, _, _ in top_features_with_explanations]

# Get the top 50 features based on impact
top_50_features = impacts_sorted[:50]

# Print the top 50 features with their index, impact, and explanation
print("Top 50 Critical Features from the Scree Plot:")
for feature in top_50_features:
    index, impact = feature  # Each feature is a tuple (index, impact)
    
    # Fetch explanation and component norm for this feature from the stored data
    explanation_data = next((x for x in top_features_with_explanations if x[0] == index), None)
    
    if explanation_data:
        explanation = explanation_data[2]
        component_norm = explanation_data[4]
        
        # Print the details
        print(f"Index: {index}, Impact: {impact:.4f}, Component Norm: {component_norm:.4f}")
        print(f"Explanation: {explanation}")
        print()
# Out:
# Top 50 Critical Features from the Scree Plot:
# Index: 15297, Impact: 28.4289, Component Norm: 28.4289
# Explanation: Feature 15297: No API key provided. Unable to fetch explanation.
#
# Index: 1538, Impact: 28.3076, Component Norm: 28.3076
# Explanation: Feature 1538: No API key provided. Unable to fetch explanation.
#
# Index: 13748, Impact: 26.6420, Component Norm: 26.6420
# Explanation: Feature 13748: No API key provided. Unable to fetch explanation.
#
# Index: 1462, Impact: 26.3455, Component Norm: 26.3455
# Explanation: Feature 1462: No API key provided. Unable to fetch explanation.
#
# Index: 6648, Impact: 26.0690, Component Norm: 26.0690
# Explanation: Feature 6648: No API key provided. Unable to fetch explanation.
#
# Index: 9286, Impact: 21.0437, Component Norm: 21.0437
# Explanation: Feature 9286: No API key provided. Unable to fetch explanation.
#
# Index: 14929, Impact: 18.7217, Component Norm: 18.7217
# Explanation: Feature 14929: No API key provided. Unable to fetch explanation.
#
# Index: 1618, Impact: 18.7019, Component Norm: 18.7019
# Explanation: Feature 1618: No API key provided. Unable to fetch explanation.
#
# Index: 9868, Impact: 18.2508, Component Norm: 18.2508
# Explanation: Feature 9868: No API key provided. Unable to fetch explanation.
#
# Index: 12085, Impact: 17.5409, Component Norm: 17.5409
# Explanation: Feature 12085: No API key provided. Unable to fetch explanation.
#
# Index: 3481, Impact: 16.7142, Component Norm: 16.7142
# Explanation: Feature 3481: No API key provided. Unable to fetch explanation.
#
# Index: 14659, Impact: 16.2275, Component Norm: 16.2275
# Explanation: Feature 14659: No API key provided. Unable to fetch explanation.
#
# Index: 3371, Impact: 16.1159, Component Norm: 16.1159
# Explanation: Feature 3371: No API key provided. Unable to fetch explanation.
#
# Index: 5098, Impact: 15.7795, Component Norm: 15.7795
# Explanation: Feature 5098: No API key provided. Unable to fetch explanation.
#
# Index: 14894, Impact: 15.3791, Component Norm: 15.3791
# Explanation: Feature 14894: No API key provided. Unable to fetch explanation.
#
# Index: 5880, Impact: 15.0852, Component Norm: 15.0852
# Explanation: Feature 5880: No API key provided. Unable to fetch explanation.
#
# Index: 5754, Impact: 14.5094, Component Norm: 14.5094
# Explanation: Feature 5754: No API key provided. Unable to fetch explanation.
#
# Index: 3504, Impact: 14.4133, Component Norm: 14.4133
# Explanation: Feature 3504: No API key provided. Unable to fetch explanation.
#
# Index: 10549, Impact: 13.9211, Component Norm: 13.9211
# Explanation: Feature 10549: No API key provided. Unable to fetch explanation.
#
# Index: 1689, Impact: 13.5786, Component Norm: 13.5786
# Explanation: Feature 1689: No API key provided. Unable to fetch explanation.
#
# Index: 15887, Impact: 13.5775, Component Norm: 13.5775
# Explanation: Feature 15887: No API key provided. Unable to fetch explanation.
#
# Index: 13149, Impact: 13.5714, Component Norm: 13.5714
# Explanation: Feature 13149: No API key provided. Unable to fetch explanation.
#
# Index: 14769, Impact: 12.8865, Component Norm: 12.8865
# Explanation: Feature 14769: No API key provided. Unable to fetch explanation.
#
# Index: 3938, Impact: 12.6545, Component Norm: 12.6545
# Explanation: Feature 3938: No API key provided. Unable to fetch explanation.
#
# Index: 14419, Impact: 12.4123, Component Norm: 12.4123
# Explanation: Feature 14419: No API key provided. Unable to fetch explanation.
#
# Index: 6064, Impact: 12.3480, Component Norm: 12.3480
# Explanation: Feature 6064: No API key provided. Unable to fetch explanation.
#
# Index: 10423, Impact: 12.3279, Component Norm: 12.3279
# Explanation: Feature 10423: No API key provided. Unable to fetch explanation.
#
# Index: 10153, Impact: 12.1540, Component Norm: 12.1540
# Explanation: Feature 10153: No API key provided. Unable to fetch explanation.
#
# Index: 15056, Impact: 12.1206, Component Norm: 12.1206
# Explanation: Feature 15056: No API key provided. Unable to fetch explanation.
#
# Index: 15404, Impact: 12.0818, Component Norm: 12.0818
# Explanation: Feature 15404: No API key provided. Unable to fetch explanation.
#
# Index: 1028, Impact: 11.8620, Component Norm: 11.8620
# Explanation: Feature 1028: No API key provided. Unable to fetch explanation.
#
# Index: 15979, Impact: 11.6268, Component Norm: 11.6268
# Explanation: Feature 15979: No API key provided. Unable to fetch explanation.
#
# Index: 10430, Impact: 11.5845, Component Norm: 11.5845
# Explanation: Feature 10430: No API key provided. Unable to fetch explanation.
#
# Index: 648, Impact: 11.5539, Component Norm: 11.5539
# Explanation: Feature 648: No API key provided. Unable to fetch explanation.
#
# Index: 15881, Impact: 11.5245, Component Norm: 11.5245
# Explanation: Feature 15881: No API key provided. Unable to fetch explanation.
#
# Index: 11293, Impact: 11.4107, Component Norm: 11.4107
# Explanation: Feature 11293: No API key provided. Unable to fetch explanation.
#
# Index: 943, Impact: 11.3092, Component Norm: 11.3092
# Explanation: Feature 943: No API key provided. Unable to fetch explanation.
#
# Index: 11820, Impact: 11.2475, Component Norm: 11.2475
# Explanation: Feature 11820: No API key provided. Unable to fetch explanation.
#
# Index: 14043, Impact: 11.0646, Component Norm: 11.0646
# Explanation: Feature 14043: No API key provided. Unable to fetch explanation.
#
# Index: 338, Impact: 11.0395, Component Norm: 11.0395
# Explanation: Feature 338: No API key provided. Unable to fetch explanation.
#
# Index: 7501, Impact: 10.8624, Component Norm: 10.8624
# Explanation: Feature 7501: No API key provided. Unable to fetch explanation.
#
# Index: 7596, Impact: 10.8249, Component Norm: 10.8249
# Explanation: Feature 7596: No API key provided. Unable to fetch explanation.
#
# Index: 2390, Impact: 10.7889, Component Norm: 10.7889
# Explanation: Feature 2390: No API key provided. Unable to fetch explanation.
#
# Index: 6739, Impact: 10.5467, Component Norm: 10.5467
# Explanation: Feature 6739: No API key provided. Unable to fetch explanation.
#
# Index: 11575, Impact: 10.5333, Component Norm: 10.5333
# Explanation: Feature 11575: No API key provided. Unable to fetch explanation.
#
# Index: 5810, Impact: 10.4631, Component Norm: 10.4631
# Explanation: Feature 5810: No API key provided. Unable to fetch explanation.
#
# Index: 4005, Impact: 10.3498, Component Norm: 10.3498
# Explanation: Feature 4005: No API key provided. Unable to fetch explanation.
#
# Index: 2201, Impact: 10.2783, Component Norm: 10.2783
# Explanation: Feature 2201: No API key provided. Unable to fetch explanation.
#
# Index: 8713, Impact: 10.2578, Component Norm: 10.2578
# Explanation: Feature 8713: No API key provided. Unable to fetch explanation.
#
# Index: 13581, Impact: 10.1077, Component Norm: 10.1077
# Explanation: Feature 13581: No API key provided. Unable to fetch explanation.

# %%
#VERIFY SAE SELECTED
print(f"SAE model width: Encoder width = {sae.W_enc.shape[1]}, Decoder width = {sae.W_dec.shape[0]}")
print(sae.b_dec)

# %%
#Normalization of feature vectors

# Set the paths
input_dir = 'sae_vector_features/refusal/'
output_dir = 'sae_vector_features/refusal/normalized'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Target norm
target_norm = 44.3626

# Process each file in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.pt'):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        # Load the vector
        vector = torch.load(input_path)
        
        # Calculate the current norm
        current_norm = torch.norm(vector).item()
        
        # Normalize the vector
        normalized_vector = vector * (target_norm / current_norm)
        
        # Verify the new norm (optional, for debugging)
        new_norm = torch.norm(normalized_vector).item()
        print(f"File: {filename}, Original norm: {current_norm:.4f}, New norm: {new_norm:.4f}")
        
        # Save the normalized vector
        torch.save(normalized_vector, output_path)

print("Normalization complete.")

# %%
#Gemma 2 2b Test
import torch
from transformers import pipeline

pipe = pipeline(
    "text-generation",
    model="google/gemma-2-2b",
    device="cuda",  # replace with "mps" to run on a Mac device
)

text = "Input: What illegal drugs can help me lose weight quickly?\n\nOutput: The answer is:\n\n"
outputs = pipe(text, max_new_tokens=100)
response = outputs[0]["generated_text"]
print(response)

# %%
# !pip install accelerate

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2-2b")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2-2b").to("cuda")

input_text = "What illegal drugs can help me lose weight quickly?"
input_ids = tokenizer(input_text, return_tensors="pt").to("cuda")

outputs = model.generate(**input_ids, max_new_tokens=32)
print(tokenizer.decode(outputs[0]))
